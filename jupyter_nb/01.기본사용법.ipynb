# %% [markdown]
# ```
# <제목>
# # 제목1
# ## 제목2
# ### 제목3
#
# <인용구>
# > 중요한 것은 꺽이지 않는 마음
#
# <순서 있는 목록>
# 1. 첫번째
# 2. 두번째
# 3. 세번째
#
# <순서 없는 목록>
# - 베인
# - 티모
# - 이즈리얼
#
# ```

# %% [markdown]
# <제목>
# # 제목1
# ## 제목2
# ### 제목3

# %% [markdown]
# <인용구>
# > 중요한 것은 꺽이지 않는 마음

# %% [markdown]
# <순서 있는 목록>
# 1. 첫번째
# 2. 두번째
# 3. 세번째

# %% [markdown]
# <순서 없는 목록>
# - 베인
# - 티모
# - 이즈리얼

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
a = 5
b = 10
c = a + b
c
# Out:
# 15

# %%
f'{a} + {b} = {c}'
# Out:
# '5 + 10 = 15'

# %% [markdown]
# ### nbformat 및 nbconvert 업데이트
# ```Bash
# pip install --upgrade nbformat nbconvert
# ```
