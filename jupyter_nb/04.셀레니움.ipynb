# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

import os
from config import account 

USERID = os.environ.get("USERID")
USERPW = os.environ.get("USERPW")

# %%
NAVER_ID = USERID
NAVER_PW = USERPW

# NAVER_ID = account.NAVER_ID
# NAVER_PW = account.NAVER_PW
# NAVER_ID, NAVER_PW

# %% [markdown]
# 1. ChromeDriver 경로 설정 확인
# - webdriver.Chrome()을 사용할 때, 크롬 드라이버의 경로를 문자열로 직접 전달하면 오류가 발생할 수 있습니다.
# 2. Selenium 버전 확인
# - Selenium이 업데이트되면서 크롬 드라이버를 직접 지정할 필요가 없어졌습니다.
# - `pip install -upgrade selenium` 명령을 실행하여 최신 버전으로 업데이트하세요.
# 3. 자동 설치 라이브러리 사용
# - `chromedirver-autoinstaller`를 사용하면 크롬 드라이버를 자동으로 설치할 수 있다.
#     ```python
#     import chromedriver_autoinstaller
#     chromedriver_autoinstaller.install()
#     ```
# - 수정 전
#     ```python
#     driver = webdriver.Chrome("C:/Python/driver/chromedriver-win64/chromedriver.exe")
#     ```
# - 수정 후
#     ```python
#     driver = webdriver.Chrome()
#     ```

# %%
# driver = webdriver.Chrome("C:/Python/driver/chromedriver-win64/chromedriver.exe")
driver = webdriver.Chrome()

# %%
driver.get("https://www.naver.com/")

# %%
# Naver login 클릭
driver.find_element(By.XPATH, '//*[@id="account"]/div/a').click()

# %%
# 이전 페이지로 이동
driver.back()

# %%
# Naver login 클릭
login_btn = driver.find_element(By.CSS_SELECTOR, "#account > div > a")
login_btn.click()

# %%
# 아이디 입력
naver_id = driver.find_element(By.CSS_SELECTOR, "#id")
naver_id.send_keys(NAVER_ID)

# %%
# 비밀번호 입력
naver_pw = driver.find_element(By.CSS_SELECTOR, "#pw")
naver_pw.send_keys(NAVER_PW)

# %%
# 로그인 클릭
login_btn = driver.find_element(By.CSS_SELECTOR, "#log\.login")
login_btn.click()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\.'
# <>:2: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\bigpy\AppData\Local\Temp\ipykernel_28508\3788987245.py:2: SyntaxWarning: invalid escape sequence '\.'
#   login_btn = driver.find_element(By.CSS_SELECTOR, "#log\.login")

# %%
# 비밀번호 입력
naver_pw = driver.find_element(By.CSS_SELECTOR, "#pw")
naver_pw.send_keys(NAVER_PW)
